# %% [markdown]
# <a href="https://colab.research.google.com/github/anshatwork-007/Final-Project-first-year-Student-Performance-Analysis-/blob/main/Final_Project_first_year_Student_Performance_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name: Ansh Yadav
# # Branch: ENTC
# # Batch: 2025-29
#
# ## Title: Final Project first year Student Performance Analysis

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#    Average Score
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  total  \
# 995               completed          88             99             95    282
# 996                    none          62             55             55    172
# 997               completed          59             71             65    195
# 998               completed          68             78             77    223
# 999                    none          77             86             86    249
#
#      Average Score
# 995      94.000000
# 996      57.333333
# 997      65.000000
# ...

# %% [markdown]
# # Step 1: Setup and File Upload

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('StudentsPerformance.csv')

# Rename columns for easier typing and standard formatting
df.rename(columns={
    'race/ethnicity': 'race_ethnicity',
    'parental level of education': 'parent_education',
    'test preparation course': 'test_prep',
    'math score': 'math_score',
    'reading score': 'reading_score',
    'writing score': 'writing_score',
    'Average Score': 'average_score'
}, inplace=True)

print("Dataset loaded successfully!")
print(df)
# Out:
# Dataset loaded successfully!
#      gender race_ethnicity    parent_education         lunch  test_prep  \
# 0    female        group B   bachelor's degree      standard       none
# 1    female        group C        some college      standard  completed
# 2    female        group B     master's degree      standard       none
# 3      male        group A  associate's degree  free/reduced       none
# 4      male        group C        some college      standard       none
# ..      ...            ...                 ...           ...        ...
# 995  female        group E     master's degree      standard  completed
# 996    male        group C         high school  free/reduced       none
# 997  female        group C         high school  free/reduced  completed
# 998  female        group D        some college      standard  completed
# 999  female        group D        some college  free/reduced       none
#
#      math_score  reading_score  writing_score  total  average_score
# ...

# %% [markdown]
# # 🔍 Step 2 – Basic Dataset Inspection

# %%
# Checking the overall shape, data types, and first few rows to understand the dataset structure.
print(f"Shape of dataset: {df.shape}\n")
print("--- First 5 Rows ---")
display(df.head())
print("\n--- Last 5 Rows ---")
display(df.tail())
print("\n--- Data Types ---")
print(df.dtypes)
print("\n--- Dataset Info ---")
df.info()
print(f"\nColumns: {list(df.columns)}")
# Out:
# Shape of dataset: (1000, 10)
#
# --- First 5 Rows ---
#    gender race_ethnicity    parent_education         lunch  test_prep  \
# 0  female        group B   bachelor's degree      standard       none
# 1  female        group C        some college      standard  completed
# 2  female        group B     master's degree      standard       none
# 3    male        group A  associate's degree  free/reduced       none
# 4    male        group C        some college      standard       none
#
#    math_score  reading_score  writing_score  total  average_score
# 0          72             72             74    218      72.666667
# 1          69             90             88    247      82.333333
# 2          90             95             93    278      92.666667
# 3          47             57             44    148      49.333333
# 4          76             78             75    229      76.333333
# --- Last 5 Rows ---
#      gender race_ethnicity parent_education         lunch  test_prep  \
# ...

# %% [markdown]
# # Step 3 – Descriptive Statistics

# %%
# Generating basic statistical measures like mean, median, and standard deviation for numerical columns.
print("--- Numerical Summary ---")
display(df.describe())

print("\n--- Individual Statistics ---")
print(f"Mean Math Score: {df['math_score'].mean():.2f}")
print(f"Median Reading Score: {df['reading_score'].median()}")
print(f"Std Dev of Writing Score: {df['writing_score'].std():.2f}")
# Out:
# --- Numerical Summary ---
#        math_score  reading_score  writing_score        total  average_score
# count  1000.00000    1000.000000    1000.000000  1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000   203.312000      67.770667
# std      15.16308      14.600192      15.195657    42.771978      14.257326
# min       0.00000      17.000000      10.000000    27.000000       9.000000
# 25%      57.00000      59.000000      57.750000   175.000000      58.333333
# 50%      66.00000      70.000000      69.000000   205.000000      68.333333
# 75%      77.00000      79.000000      79.000000   233.000000      77.666667
# max     100.00000     100.000000     100.000000   300.000000     100.000000
# --- Individual Statistics ---
# Mean Math Score: 66.09
# Median Reading Score: 70.0
# Std Dev of Writing Score: 15.20

# %% [markdown]
# # Step 4 – Missing Value Analysis

# %%
# Check for nulls
missing_data = df.isnull().sum()
print("--- Missing Values Count ---")
print(missing_data)

# Check percentage of missing values
missing_percent = (df.isnull().sum() / len(df)) * 100
print("\n--- Missing Values Percentage ---")
print(missing_percent)

# If there were missing values, you could drop them using df.dropna(inplace=True)
# Out:
# --- Missing Values Count ---
# gender              0
# race_ethnicity      0
# parent_education    0
# lunch               0
# test_prep           0
# math_score          0
# reading_score       0
# writing_score       0
# total               0
# average_score       0
# dtype: int64
#
# --- Missing Values Percentage ---
# gender              0.0
# race_ethnicity      0.0
# parent_education    0.0
# lunch               0.0
# test_prep           0.0
# math_score          0.0
# reading_score       0.0
# writing_score       0.0
# total               0.0
# average_score       0.0
# dtype: float64

# %% [markdown]
# # Step 5 – Frequency Counts (value_counts)

# %%
# Counting the occurrences of each distinct category within our categorical variables.
categorical_cols = ['gender', 'race_ethnicity', 'parent_education', 'lunch', 'test_prep']

for col in categorical_cols:
    print(f"\n--- Frequency for {col} ---")
    print(df[col].value_counts())
# Out:
# --- Frequency for gender ---
# gender
# female    518
# male      482
# Name: count, dtype: int64
#
# --- Frequency for race_ethnicity ---
# race_ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64
#
# --- Frequency for parent_education ---
# parent_education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64
#
# --- Frequency for lunch ---
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64
#
# --- Frequency for test_prep ---
# test_prep
# none         642
# completed    358
# Name: count, dtype: int64

# %% [markdown]
# # Step 6 – Unique Values (unique & nunique)

# %%
# Identifying the exact unique categories present in each column to understand data variety.
print("--- Number of Unique Values per Column ---")
print(df.nunique())

print("\n--- Unique Values in Categorical Columns ---")
for col in categorical_cols:
    print(f"{col}: {df[col].unique()}")
# Out:
# --- Number of Unique Values per Column ---
# gender                2
# race_ethnicity        5
# parent_education      6
# lunch                 2
# test_prep             2
# math_score           81
# reading_score        72
# writing_score        77
# total               194
# average_score       194
# dtype: int64
#
# --- Unique Values in Categorical Columns ---
# gender: ['female' 'male']
# race_ethnicity: ['group B' 'group C' 'group A' 'group D' 'group E']
# parent_education: ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# lunch: ['standard' 'free/reduced']
# test_prep: ['none' 'completed']

# %% [markdown]
# # Step 7 – Percentage Distribution

# %%
for col in categorical_cols:
    print(f"\n--- Percentage Distribution for {col} ---")
    print(round(df[col].value_counts(normalize=True) * 100, 2).astype(str) + '%')
# Out:
# --- Percentage Distribution for gender ---
# gender
# female    51.8%
# male      48.2%
# Name: proportion, dtype: object
#
# --- Percentage Distribution for race_ethnicity ---
# race_ethnicity
# group C    31.9%
# group D    26.2%
# group B    19.0%
# group E    14.0%
# group A     8.9%
# Name: proportion, dtype: object
#
# --- Percentage Distribution for parent_education ---
# parent_education
# some college          22.6%
# associate's degree    22.2%
# high school           19.6%
# some high school      17.9%
# bachelor's degree     11.8%
# master's degree        5.9%
# Name: proportion, dtype: object
#
# --- Percentage Distribution for lunch ---
# lunch
# standard        64.5%
# free/reduced    35.5%
# Name: proportion, dtype: object
#
# --- Percentage Distribution for test_prep ---
# test_prep
# none         64.2%
# completed    35.8%
# Name: proportion, dtype: object

# %% [markdown]
# # Step 8 – Filtering Data

# %%
# 1. Students who completed test prep course
prep_completed = df[df['test_prep'] == 'completed']

# 2. Students on free/reduced lunch
free_lunch = df[df['lunch'] == 'free/reduced']

# 3. Students scoring above 90 average
top_students = df[df['average_score'] >= 90]

# 4. Students with math score < 40 (at-risk)
math_risk = df[df['math_score'] < 40]

# 5. Female students from group E
female_group_E = df[(df['gender'] == 'female') & (df['race_ethnicity'] == 'group E')]

print(f"Number of top students (Avg >= 90): {len(top_students)}")
print(f"Number of at-risk math students: {len(math_risk)}")
# Out:
# Number of top students (Avg >= 90): 52
# Number of at-risk math students: 40

# %% [markdown]
# # Step 9 – Cross Tabulation (pd.crosstab)

# %%
print("--- Gender vs Test Prep ---")
display(pd.crosstab(df['gender'], df['test_prep']))

print("\n--- Race/Ethnicity vs Lunch ---")
display(pd.crosstab(df['race_ethnicity'], df['lunch']))

print("\n--- Parent Education vs Test Prep ---")
display(pd.crosstab(df['parent_education'], df['test_prep']))
# Out:
# --- Gender vs Test Prep ---
# test_prep  completed  none
# gender
# female           184   334
# male             174   308
# --- Race/Ethnicity vs Lunch ---
# lunch           free/reduced  standard
# race_ethnicity
# group A                   36        53
# group B                   69       121
# group C                  114       205
# group D                   95       167
# group E                   41        99
# --- Parent Education vs Test Prep ---
# test_prep           completed  none
# parent_education
# associate's degree         82   140
# bachelor's degree          46    72
# high school                56   140
# master's degree            20    39
# some college               77   149
# some high school           77   102

# %% [markdown]
# # Step 10 – Grouping Data (groupby)

# %%
# Mean scores grouped by gender
print("--- Mean Scores by Gender ---")
display(df.groupby('gender')[['math_score', 'reading_score', 'writing_score']].mean())

# Max/min scores by race/ethnicity
print("\n--- Max & Min Math Scores by Race/Ethnicity ---")
display(df.groupby('race_ethnicity')['math_score'].agg(['max', 'min']))
# Out:
# --- Mean Scores by Gender ---
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203
# --- Max & Min Math Scores by Race/Ethnicity ---
#                 max  min
# race_ethnicity
# group A         100   28
# group B          97    8
# group C          98    0
# group D         100   26
# group E         100   30

# %% [markdown]
# # Step 11 – Sorting

# %%
# Sort by Average Score descending (Top 5 performers)
top_performers = df.sort_values(by='average_score', ascending=False).head()
display(top_performers)

# Sort by Math Score ascending (Bottom 5 students)
struggling_math = df.sort_values(by='math_score', ascending=True).head()
display(struggling_math)
# Out:
#      gender race_ethnicity    parent_education     lunch  test_prep  \
# 916    male        group E   bachelor's degree  standard  completed
# 962  female        group E  associate's degree  standard       none
# 458  female        group E   bachelor's degree  standard       none
# 114  female        group E   bachelor's degree  standard  completed
# 712  female        group D        some college  standard       none
#
#      math_score  reading_score  writing_score  total  average_score
# 916         100            100            100    300     100.000000
# 962         100            100            100    300     100.000000
# 458         100            100            100    300     100.000000
# 114          99            100            100    299      99.666667
# 712          98            100             99    297      99.000000
#      gender race_ethnicity  parent_education         lunch test_prep  \
# 59   female        group C  some high school  free/reduced      none
# ...

# %% [markdown]
# # Step 12 – Adding Derived Columns

# %%
# 1. Grade Category
def assign_grade(score):
    if score >= 80: return 'Distinction'
    elif score >= 60: return 'First Class'
    elif score >= 40: return 'Pass'
    else: return 'Fail'

df['grade_category'] = df['average_score'].apply(assign_grade)

# 2. Score Gap (Reading - Math)
df['score_gap'] = df['reading_score'] - df['math_score']

print("--- Data with New Derived Columns ---")
display(df[['math_score', 'reading_score', 'average_score', 'grade_category', 'score_gap']].head())
# Out:
# --- Data with New Derived Columns ---
#    math_score  reading_score  average_score grade_category  score_gap
# 0          72             72      72.666667    First Class          0
# 1          69             90      82.333333    Distinction         21
# 2          90             95      92.666667    Distinction          5
# 3          47             57      49.333333           Pass         10
# 4          76             78      76.333333    First Class          2

# %% [markdown]
# # Step 13 – Visualizations

# %%
# Set a universal style for plots
sns.set_theme(style="whitegrid")

# Create a figure with subplots
fig, axes = plt.subplots(3, 2, figsize=(16, 18))
plt.subplots_adjust(hspace=0.4, wspace=0.3)

# 1. Bar Chart: Frequency of each race/ethnicity group
sns.countplot(data=df, x='race_ethnicity', order=df['race_ethnicity'].value_counts().index, ax=axes[0, 0], palette='viridis')
axes[0, 0].set_title('Frequency of Race/Ethnicity Groups')

# 2. Pie Chart: % who completed test preparation course
prep_counts = df['test_prep'].value_counts()
axes[0, 1].pie(prep_counts, labels=prep_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue'], startangle=90)
axes[0, 1].set_title('Test Preparation Course Completion %')

# 3. Histogram: Distribution of Math Scores
sns.histplot(df['math_score'], bins=20, kde=True, color='purple', ax=axes[1, 0])
axes[1, 0].set_title('Distribution of Math Scores')

# 4. Grouped Bar: Avg scores by gender
scores_gender = df.groupby('gender')[['math_score', 'reading_score', 'writing_score']].mean().reset_index()
scores_gender_melted = scores_gender.melt(id_vars='gender', var_name='Subject', value_name='Score')
sns.barplot(data=scores_gender_melted, x='Subject', y='Score', hue='gender', ax=axes[1, 1], palette='Set2')
axes[1, 1].set_title('Average Scores by Gender')

# 5. Horizontal Bar: Avg Average Score by parental level of education
avg_by_edu = df.groupby('parent_education')['average_score'].mean().sort_values()
sns.barplot(y=avg_by_edu.index, x=avg_by_edu.values, ax=axes[2, 0], palette='magma')
axes[2, 0].set_title('Avg Total Score by Parental Education')
axes[2, 0].set_xlabel('Average Score')

# 6. Bar Chart: Distribution of Grade Category
sns.countplot(data=df, x='grade_category', order=['Distinction', 'First Class', 'Pass', 'Fail'], ax=axes[2, 1], palette='coolwarm')
axes[2, 1].set_title('Distribution of Grade Categories')

plt.show()
# Out:
# /tmp/ipykernel_10895/2956051903.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='race_ethnicity', order=df['race_ethnicity'].value_counts().index, ax=axes[0, 0], palette='viridis')
# /tmp/ipykernel_10895/2956051903.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=avg_by_edu.index, x=avg_by_edu.values, ax=axes[2, 0], palette='magma')
# /tmp/ipykernel_10895/2956051903.py:34: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...
